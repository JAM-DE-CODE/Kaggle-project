# %% [markdown]
# <a href="https://www.kaggle.com/code/judithamarachi/data-visualization-project?scriptVersionId=109122789" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/netflix-movies-and-tv-shows-october-2022/netflix movie.csv

# %%
my_filepath = "../input/netflix-movies-and-tv-shows-october-2022/netflix movie.csv"

# %%
my_data = pd.read_csv('../input/netflix-movies-and-tv-shows-october-2022/netflix movie.csv')

# %%
my_data.head()
# Out:
#             White Chicks  PG-13  \
# 0    Lucky Number Slevin      R
# 1         Grey's Anatomy  TV-14
# 2           Prison Break  TV-14
# 3  How I Met Your Mother  TV-PG
# 4           Supernatural  TV-14
#
#   crude and sexual humor, language and some drug content   80  2004    82  \
# 0  strong violence, sexual content and adult lang...      100  2006   NaN
# 1  Parents strongly cautioned. May be unsuitable ...       90  2016  98.0
# 2  Parents strongly cautioned. May be unsuitable ...       90  2008  98.0
# 3  Parental guidance suggested. May not be suitab...       70  2014  94.0
# 4  Parents strongly cautioned. May be unsuitable ...       90  2016  95.0
#
#    80.1
# 0    82
# 1    80
# 2    80
# 3    80
# 4    80

# %%
my_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 7 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   White Chicks                                            999 non-null    object
#  1   PG-13                                                   999 non-null    object
#  2   crude and sexual humor, language and some drug content  940 non-null    object
#  3   80                                                      999 non-null    int64
#  4   2004                                                    999 non-null    int64
#  5   82                                                      604 non-null    float64
#  6   80.1                                                    999 non-null    int64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 54.8+ KB

# %%
my_data.describe()
# Out:
#                80         2004          82        80.1
# count  999.000000   999.000000  604.000000  999.000000
# mean    67.353353  2010.341341   84.097682   80.783784
# std     30.798431     8.880108   12.354308    0.973238
# min     10.000000  1940.000000   55.000000   80.000000
# 25%     35.000000  2007.000000   74.750000   80.000000
# 50%     60.000000  2015.000000   88.000000   80.000000
# 75%     90.000000  2016.000000   95.000000   82.000000
# max    124.000000  2017.000000   99.000000   82.000000

# %%
my_data.isna()
# Out:
#      White Chicks  PG-13  \
# 0           False  False
# 1           False  False
# 2           False  False
# 3           False  False
# 4           False  False
# ..            ...    ...
# 994         False  False
# 995         False  False
# 996         False  False
# 997         False  False
# 998         False  False
#
#      crude and sexual humor, language and some drug content     80   2004  \
# 0                                                False       False  False
# 1                                                False       False  False
# 2                                                False       False  False
# 3                                                False       False  False
# 4                                                False       False  False
# ..                                                 ...         ...    ...
# 994                                              False       False  False
# ...

# %%
my_data.isna().sum()
# Out:
# White Chicks                                                0
# PG-13                                                       0
# crude and sexual humor, language and some drug content     59
# 80                                                          0
# 2004                                                        0
# 82                                                        395
# 80.1                                                        0
# dtype: int64

# %%
my_data.columns
# Out:
# Index(['White Chicks', 'PG-13',
#        'crude and sexual humor, language and some drug content', '80', '2004',
#        '82', '80.1'],
#       dtype='object')

# %%
my_data.dropna(subset=['crude and sexual humor, language and some drug content', '82'], inplace=True)
my_data.reset_index
my_data.isna().sum()
# Out:
# White Chicks                                              0
# PG-13                                                     0
# crude and sexual humor, language and some drug content    0
# 80                                                        0
# 2004                                                      0
# 82                                                        0
# 80.1                                                      0
# dtype: int64

# %%
my_data['crude and sexual humor, language and some drug content'].fillna(my_data['crude and sexual humor, language and some drug content'].mode()[0], inplace=True)
my_data['82'].fillna(my_data['82'].mode()[0], inplace=True)
my_data.isna().sum()
# Out:
# White Chicks                                              0
# PG-13                                                     0
# crude and sexual humor, language and some drug content    0
# 80                                                        0
# 2004                                                      0
# 82                                                        0
# 80.1                                                      0
# dtype: int64

# %%
plt.figure(figsize = (10, 5))
sns.lineplot(data = my_data)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (10, 5))
sns.barplot(data = my_data)
# Out:
# <AxesSubplot:>
